# %% [markdown]
# # Importing Basic Liabraris & Dataset for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\\LetsGrowMore\\Task3\\globalterrorismdb_0718dist.csv", encoding= 'latin', low_memory=False)

# %% [markdown]
# # Data Insights & Data Cleaning

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
final_df = df[['iyear','imonth', 'iday','extended','country_txt','region_txt','city','success','suicide','attacktype1_txt',
             'targtype1_txt','gname','weaptype1_txt','nkill']]

# %%
final_df.head()
# Out:
#    iyear  imonth  iday  extended         country_txt  \
# 0   1970       7     2         0  Dominican Republic
# 1   1970       0     0         0              Mexico
# 2   1970       1     0         0         Philippines
# 3   1970       1     0         0              Greece
# 4   1970       1     0         0               Japan
#
#                     region_txt           city  success  suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# ...

# %%
final_df.shape
# Out:
# (181691, 14)

# %%
final_df.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'extended', 'country_txt', 'region_txt',
#        'city', 'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
#        'gname', 'weaptype1_txt', 'nkill'],
#       dtype='object')

# %%
final_df.rename(columns={'iyear' : 'year', 'imonth' : 'month', 'iday' : 'day', 'country_txt' : 'country', 
                         'region_txt' : 'region',  'attacktype1_txt' : 'attack type', 'targtype1_txt': 'target type',
                         'gname' : 'gang name', 'weaptype1_txt' : 'weapon type', 'nkill' : 'no of kills'}, inplace = True)

# %%
final_df.head()
# Out:
#    year  month  day  extended             country  \
# 0  1970      7    2         0  Dominican Republic
# 1  1970      0    0         0              Mexico
# 2  1970      1    0         0         Philippines
# 3  1970      1    0         0              Greece
# 4  1970      1    0         0               Japan
#
#                         region           city  success  suicide  \
# 0  Central America & Caribbean  Santo Domingo        1        0
# 1                North America    Mexico city        1        0
# 2               Southeast Asia        Unknown        1        0
# 3               Western Europe         Athens        1        0
# 4                    East Asia        Fukouka        1        0
#
#                       attack type                  target type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   year         181691 non-null  int64
#  1   month        181691 non-null  int64
#  2   day          181691 non-null  int64
#  3   extended     181691 non-null  int64
#  4   country      181691 non-null  object
#  5   region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   success      181691 non-null  int64
#  8   suicide      181691 non-null  int64
#  9   attack type  181691 non-null  object
#  10  target type  181691 non-null  object
#  11  gang name    181691 non-null  object
#  12  weapon type  181691 non-null  object
#  13  no of kills  171378 non-null  float64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 19.4+ MB

# %%
final_df.describe()
# Out:
#                 year          month            day       extended  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       0.045346
# std        13.259430       3.388303       8.814045       0.208063
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#              success        suicide    no of kills
# count  181691.000000  181691.000000  171378.000000
# mean        0.889598       0.036507       2.403272
# std         0.313391       0.187549      11.545741
# min         0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000
# ...

# %%
final_df.describe(include='O')
# Out:
#        country                      region     city        attack type  \
# count   181691                      181691   181257             181691
# unique     205                          12    36674                  9
# top       Iraq  Middle East & North Africa  Unknown  Bombing/Explosion
# freq     24636                       50474     9775              88255
#
#                         target type gang name weapon type
# count                        181691    181691      181691
# unique                           22      3537          12
# top     Private Citizens & Property   Unknown  Explosives
# freq                          43511     82782       92426

# %%
final_df.isnull().sum()
# Out:
# year               0
# month              0
# day                0
# extended           0
# country            0
# region             0
# city             434
# success            0
# suicide            0
# attack type        0
# target type        0
# gang name          0
# weapon type        0
# no of kills    10313
# dtype: int64

# %%
final_df['no of kills'] = final_df['no of kills'].fillna(0)

# %%
final_df['city'] = final_df['city'].fillna('unknown')

# %%
final_df.isnull().sum()
# Out:
# year           0
# month          0
# day            0
# extended       0
# country        0
# region         0
# city           0
# success        0
# suicide        0
# attack type    0
# target type    0
# gang name      0
# weapon type    0
# no of kills    0
# dtype: int64

# %%
final_df.duplicated().sum()
# Out:
# 15707

# %%
final_df.drop_duplicates(inplace= True)

# %%
final_df.shape
# Out:
# (165984, 14)

# %%
final_df['no of kills'] = final_df['no of kills'].astype(int)

# %%
# Exporting Cleaned Dataset for making analysis with different visualization tools like PowerBI  
final_df.to_csv("D:\\LetsGrowMore\\Task3\\TerroristDataset.csv")

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(15,12))
final_df['year'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['country'].value_counts().iloc[:10].plot(kind = 'barh',)
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['city'].value_counts().iloc[:10].plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['region'].value_counts().iloc[:10].plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['attack type'].value_counts().iloc[:10].plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['weapon type'].value_counts().iloc[:5].plot(kind = 'barh')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['gang name'].value_counts().iloc[:10].plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(15,12))
final_df['target type'].value_counts().iloc[:10].plot(kind = 'bar')
plt.show()

# %%
sns.countplot(x='extended', data=final_df)
# Out:
# <AxesSubplot:xlabel='extended', ylabel='count'>

# %%
sns.countplot(x='success', data=final_df)
# Out:
# <AxesSubplot:xlabel='success', ylabel='count'>

# %%
sns.countplot(x='suicide', data=final_df)
# Out:
# <AxesSubplot:xlabel='suicide', ylabel='count'>

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(15,10))
sns.heatmap(final_df.corr(), annot=True, square=True, cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(25,15))
sns.barplot(x = 'year', y='no of kills', data= final_df)
plt.show()

# %%
plt.figure(figsize=(25,15))
sns.lineplot(x = 'year', y='no of kills', data= final_df)
plt.show()
